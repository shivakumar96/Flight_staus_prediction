# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
import datetime

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.core.display import display, HTML
# Out:
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/2023341204.py:18: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
Airline_Data = pd.read_csv('Detailed_Statistics_Arrivals-weather.csv',parse_dates = ["Date"])
Airline_Data.head()
# Out:
#   Carrier Code       Date  Flight_Number Tail Number Origin Airport  \
# 0           UA 2022-01-01           1282      N4901U            IAD
# 1           UA 2023-01-01            604      N814UA            DEN
# 2           UA 2023-01-01           2488      N38458            EWR
# 3           UA 2023-01-01           2645      N23721            ORD
# 4           UA 2022-01-02           1282      N4901U            IAD
#
#   Scheduled Arrival Time Actual Arrival Time  \
# 0                  23:10                0:01
# 1                  14:58               14:52
# 2                  23:14               23:15
# 3                  23:57               23:47
# 4                  23:10               23:27
#
#    Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 0                                70                             76
# 1                               193                            177
# 2                                75                             62
# 3                               107                            100
# 4                                70                             64
#
#    Arrival Delay (Minutes)  ... org_snow  org_temp  org_solar_rad  \
# 0                       51  ...     0.00     13.80          11.00
# 1                       -6  ...     0.00      0.40          50.00
# 2                        1  ...     0.00     11.30          95.20
# 3                      -10  ...     6.50      4.60          31.40
# 4                       17  ...     0.00     15.30          20.50
#
#    org_wind_spd  dest_clouds  dest_pres  dest_snow dest_temp  dest_solar_rad  \
# 0          1.50          100     991.20       0.00      5.40            8.60
# 1          2.40           92     998.40       0.00      6.80           37.50
# 2          3.70           92     998.40       0.00      6.80           37.50
# 3          2.20           92     998.40       0.00      6.80           37.50
# 4          2.60           98     995.80      50.50     -0.70           17.50
#
#    dest_wind_spd
# 0           2.80
# 1           4.10
# 2           4.10
# 3           4.10
# 4           4.20
#
# [5 rows x 30 columns]

# %%
Airline_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 30 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Carrier Code                              1361 non-null   object
#  1   Date                                      1361 non-null   datetime64[ns]
#  2   Flight_Number                             1361 non-null   int64
#  3   Tail Number                               1342 non-null   object
#  4   Origin Airport                            1361 non-null   object
#  5   Scheduled Arrival Time                    1361 non-null   object
#  6   Actual Arrival Time                       1361 non-null   object
#  7   Scheduled Elapsed Time (Minutes)          1361 non-null   int64
#  8   Actual Elapsed Time (Minutes)             1361 non-null   int64
#  9   Arrival Delay (Minutes)                   1361 non-null   int64
#  10  Wheels-on Time                            1361 non-null   object
#  11  Taxi-In time (Minutes)                    1361 non-null   int64
#  12  Delay Carrier (Minutes)                   1361 non-null   int64
#  13  Delay Weather (Minutes)                   1361 non-null   int64
#  14  Delay National Aviation System (Minutes)  1361 non-null   int64
#  15  Delay Security (Minutes)                  1361 non-null   int64
#  16  Delay Late Aircraft Arrival (Minutes)     1361 non-null   int64
#  17  month                                     1361 non-null   object
#  18  org_clouds                                1361 non-null   int64
#  19  org_pres                                  1361 non-null   float64
#  20  org_snow                                  1361 non-null   float64
#  21  org_temp                                  1361 non-null   float64
#  22  org_solar_rad                             1361 non-null   float64
#  23  org_wind_spd                              1361 non-null   float64
#  24  dest_clouds                               1361 non-null   int64
#  25  dest_pres                                 1361 non-null   float64
#  26  dest_snow                                 1361 non-null   float64
#  27  dest_temp                                 1361 non-null   float64
#  28  dest_solar_rad                            1361 non-null   float64
#  29  dest_wind_spd                             1361 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(12), object(7)
# memory usage: 319.1+ KB

# %%
Airline_Data.isna().sum()
print(Airline_Data.columns)
# Out:
# Carrier Code                                 0
# Date                                         0
# Flight_Number                                0
# Tail Number                                 19
# Origin Airport                               0
# Scheduled Arrival Time                       0
# Actual Arrival Time                          0
# Scheduled Elapsed Time (Minutes)             0
# Actual Elapsed Time (Minutes)                0
# Arrival Delay (Minutes)                      0
# Wheels-on Time                               0
# Taxi-In time (Minutes)                       0
# Delay Carrier (Minutes)                      0
# Delay Weather (Minutes)                      0
# Delay National Aviation System (Minutes)     0
# Delay Security (Minutes)                     0
# Delay Late Aircraft Arrival (Minutes)        0
# month                                        0
# org_clouds                                   0
# org_pres                                     0
# org_snow                                     0
# org_temp                                     0
# org_solar_rad                                0
# org_wind_spd                                 0
# dest_clouds                                  0
# dest_pres                                    0
# dest_snow                                    0
# dest_temp                                    0
# dest_solar_rad                               0
# dest_wind_spd                                0
# dtype: int64
# Index(['Carrier Code', 'Date', 'Flight_Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
#        'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
#        'Delay Late Aircraft Arrival (Minutes)', 'month', 'org_clouds',
#        'org_pres', 'org_snow', 'org_temp', 'org_solar_rad', 'org_wind_spd',
#        'dest_clouds', 'dest_pres', 'dest_snow', 'dest_temp', 'dest_solar_rad',
#        'dest_wind_spd'],
#       dtype='object')

# %%
month_labels = list(Airline_Data['month'].unique())
print(month_labels)
Airline_Data['month'] = Airline_Data['month'].apply(lambda x : month_labels.index(x) +1 )
Airline_Data.info()
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 30 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Carrier Code                              1361 non-null   object
#  1   Date                                      1361 non-null   datetime64[ns]
#  2   Flight_Number                             1361 non-null   int64
#  3   Tail Number                               1342 non-null   object
#  4   Origin Airport                            1361 non-null   object
#  5   Scheduled Arrival Time                    1361 non-null   object
#  6   Actual Arrival Time                       1361 non-null   object
#  7   Scheduled Elapsed Time (Minutes)          1361 non-null   int64
#  8   Actual Elapsed Time (Minutes)             1361 non-null   int64
#  9   Arrival Delay (Minutes)                   1361 non-null   int64
#  10  Wheels-on Time                            1361 non-null   object
#  11  Taxi-In time (Minutes)                    1361 non-null   int64
#  12  Delay Carrier (Minutes)                   1361 non-null   int64
#  13  Delay Weather (Minutes)                   1361 non-null   int64
#  14  Delay National Aviation System (Minutes)  1361 non-null   int64
#  15  Delay Security (Minutes)                  1361 non-null   int64
#  16  Delay Late Aircraft Arrival (Minutes)     1361 non-null   int64
#  17  month                                     1361 non-null   int64
#  18  org_clouds                                1361 non-null   int64
#  19  org_pres                                  1361 non-null   float64
#  20  org_snow                                  1361 non-null   float64
#  21  org_temp                                  1361 non-null   float64
#  22  org_solar_rad                             1361 non-null   float64
#  23  org_wind_spd                              1361 non-null   float64
#  24  dest_clouds                               1361 non-null   int64
#  25  dest_pres                                 1361 non-null   float64
#  26  dest_snow                                 1361 non-null   float64
#  27  dest_temp                                 1361 non-null   float64
#  28  dest_solar_rad                            1361 non-null   float64
#  29  dest_wind_spd                             1361 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(13), object(6)
# memory usage: 319.1+ KB

# %%
Airline_Data['Day'] = Airline_Data['Date'].dt.strftime('%w')
Airline_Data['Day'] = Airline_Data['Date'].dt.strftime('%w').astype(int)

# %%
required_columns = [ 'Flight_Number', 'Origin Airport', 'Scheduled Arrival Time',
       'Scheduled Elapsed Time (Minutes)', 'month', 'Day', 'org_clouds',
       'org_pres', 'org_snow', 'org_temp', 'org_wind_spd',
       'dest_clouds', 'dest_pres', 'dest_snow', 'dest_temp',
       'dest_wind_spd', 'Arrival Delay (Minutes)' ]

# %%
data_before_processsing = Airline_Data[required_columns]

# %%
data_before_processsing.head()
# Out:
#    Flight_Number Origin Airport Scheduled Arrival Time  \
# 0           1282            IAD                  23:10
# 1            604            DEN                  14:58
# 2           2488            EWR                  23:14
# 3           2645            ORD                  23:57
# 4           1282            IAD                  23:10
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                                70      1    6         100    996.90
# 1                               193      1    0          77    818.80
# 2                                75      1    0          49  1,011.60
# 3                               107      1    0          93    990.80
# 4                                70      1    0         100    996.10
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0      0.00     13.80          1.50          100     991.20       0.00
# 1      0.00      0.40          2.40           92     998.40       0.00
# 2      0.00     11.30          3.70           92     998.40       0.00
# 3      6.50      4.60          2.20           92     998.40       0.00
# 4      0.00     15.30          2.60           98     995.80      50.50
#
#    dest_temp  dest_wind_spd  Arrival Delay (Minutes)
# 0       5.40           2.80                       51
# 1       6.80           4.10                       -6
# 2       6.80           4.10                        1
# 3       6.80           4.10                      -10
# 4      -0.70           4.20                       17

# %%
data_before_processsing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Flight_Number                     1361 non-null   int64
#  1   Origin Airport                    1361 non-null   object
#  2   Scheduled Arrival Time            1361 non-null   object
#  3   Scheduled Elapsed Time (Minutes)  1361 non-null   int64
#  4   month                             1361 non-null   int64
#  5   Day                               1361 non-null   int64
#  6   org_clouds                        1361 non-null   int64
#  7   org_pres                          1361 non-null   float64
#  8   org_snow                          1361 non-null   float64
#  9   org_temp                          1361 non-null   float64
#  10  org_wind_spd                      1361 non-null   float64
#  11  dest_clouds                       1361 non-null   int64
#  12  dest_pres                         1361 non-null   float64
#  13  dest_snow                         1361 non-null   float64
#  14  dest_temp                         1361 non-null   float64
#  15  dest_wind_spd                     1361 non-null   float64
#  16  Arrival Delay (Minutes)           1361 non-null   int64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 180.9+ KB

# %%
data_before_processsing['Flight_Number'] = data_before_processsing['Flight_Number'].astype(str)
data_before_processsing['Scheduled Arrival Time'] = data_before_processsing['Scheduled Arrival Time'].apply(lambda x : (float(x.split(":")[0]) + float(x.split(":")[1])/60.0)) 
data_before_processsing['org_clouds'] = data_before_processsing['org_clouds'].astype(float)
data_before_processsing['dest_clouds'] = data_before_processsing['dest_clouds'].astype(float)


data_before_processsing.info()
data_before_processsing.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Flight_Number                     1361 non-null   object
#  1   Origin Airport                    1361 non-null   object
#  2   Scheduled Arrival Time            1361 non-null   float64
#  3   Scheduled Elapsed Time (Minutes)  1361 non-null   int64
#  4   month                             1361 non-null   int64
#  5   Day                               1361 non-null   int64
#  6   org_clouds                        1361 non-null   float64
#  7   org_pres                          1361 non-null   float64
#  8   org_snow                          1361 non-null   float64
#  9   org_temp                          1361 non-null   float64
#  10  org_wind_spd                      1361 non-null   float64
#  11  dest_clouds                       1361 non-null   float64
#  12  dest_pres                         1361 non-null   float64
#  13  dest_snow                         1361 non-null   float64
#  14  dest_temp                         1361 non-null   float64
#  15  dest_wind_spd                     1361 non-null   float64
#  16  Arrival Delay (Minutes)           1361 non-null   int64
# dtypes: float64(11), int64(4), object(2)
# memory usage: 180.9+ KB
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3672779782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['Flight_Number'] = data_before_processsing['Flight_Number'].astype(str)
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3672779782.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['Scheduled Arrival Time'] = data_before_processsing['Scheduled Arrival Time'].apply(lambda x : (float(x.split(":")[0]) + float(x.split(":")[1])/60.0))
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3672779782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['org_clouds'] = data_before_processsing['org_clouds'].astype(float)
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3672779782.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['dest_clouds'] = data_before_processsing['dest_clouds'].astype(float)
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          1282            IAD                   23.17
# 1           604            DEN                   14.97
# 2          2488            EWR                   23.23
# 3          2645            ORD                   23.95
# 4          1282            IAD                   23.17
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                                70      1    6      100.00    996.90
# 1                               193      1    0       77.00    818.80
# 2                                75      1    0       49.00  1,011.60
# 3                               107      1    0       93.00    990.80
# 4                                70      1    0      100.00    996.10
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0      0.00     13.80          1.50       100.00     991.20       0.00
# 1      0.00      0.40          2.40        92.00     998.40       0.00
# 2      0.00     11.30          3.70        92.00     998.40       0.00
# 3      6.50      4.60          2.20        92.00     998.40       0.00
# 4      0.00     15.30          2.60        98.00     995.80      50.50
#
#    dest_temp  dest_wind_spd  Arrival Delay (Minutes)
# 0       5.40           2.80                       51
# 1       6.80           4.10                       -6
# 2       6.80           4.10                        1
# 3       6.80           4.10                      -10
# 4      -0.70           4.20                       17

# %%
data_before_processsing['org_clouds'] = data_before_processsing['org_clouds'].astype(float)
data_before_processsing['dest_clouds'] = data_before_processsing['dest_clouds'].astype(float)


data_before_processsing.info()
data_before_processsing.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Flight_Number                     1361 non-null   object
#  1   Origin Airport                    1361 non-null   object
#  2   Scheduled Arrival Time            1361 non-null   float64
#  3   Scheduled Elapsed Time (Minutes)  1361 non-null   int64
#  4   month                             1361 non-null   int64
#  5   Day                               1361 non-null   int64
#  6   org_clouds                        1361 non-null   float64
#  7   org_pres                          1361 non-null   float64
#  8   org_snow                          1361 non-null   float64
#  9   org_temp                          1361 non-null   float64
#  10  org_wind_spd                      1361 non-null   float64
#  11  dest_clouds                       1361 non-null   float64
#  12  dest_pres                         1361 non-null   float64
#  13  dest_snow                         1361 non-null   float64
#  14  dest_temp                         1361 non-null   float64
#  15  dest_wind_spd                     1361 non-null   float64
#  16  Arrival Delay (Minutes)           1361 non-null   int64
# dtypes: float64(11), int64(4), object(2)
# memory usage: 180.9+ KB
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3951089219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['org_clouds'] = data_before_processsing['org_clouds'].astype(float)
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3951089219.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['dest_clouds'] = data_before_processsing['dest_clouds'].astype(float)
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          1282            IAD                   23.17
# 1           604            DEN                   14.97
# 2          2488            EWR                   23.23
# 3          2645            ORD                   23.95
# 4          1282            IAD                   23.17
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                                70      1    6      100.00    996.90
# 1                               193      1    0       77.00    818.80
# 2                                75      1    0       49.00  1,011.60
# 3                               107      1    0       93.00    990.80
# 4                                70      1    0      100.00    996.10
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0      0.00     13.80          1.50       100.00     991.20       0.00
# 1      0.00      0.40          2.40        92.00     998.40       0.00
# 2      0.00     11.30          3.70        92.00     998.40       0.00
# 3      6.50      4.60          2.20        92.00     998.40       0.00
# 4      0.00     15.30          2.60        98.00     995.80      50.50
#
#    dest_temp  dest_wind_spd  Arrival Delay (Minutes)
# 0       5.40           2.80                       51
# 1       6.80           4.10                       -6
# 2       6.80           4.10                        1
# 3       6.80           4.10                      -10
# 4      -0.70           4.20                       17

# %%
def classify_status(delay):
    if delay <= -10:
        return 'Early'
    elif delay >= -10 and delay <= 10:
        return 'On-time'
    elif delay > 10 and delay <= 30:
        return 'Late'
    else:
        return 'Severely late'

# %%
data_before_processsing['Status'] = data_before_processsing['Arrival Delay (Minutes)'].apply(classify_status)

data_before_processsing.head()
# Out:
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/3200622467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_before_processsing['Status'] = data_before_processsing['Arrival Delay (Minutes)'].apply(classify_status)
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          1282            IAD                   23.17
# 1           604            DEN                   14.97
# 2          2488            EWR                   23.23
# 3          2645            ORD                   23.95
# 4          1282            IAD                   23.17
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                                70      1    6      100.00    996.90
# 1                               193      1    0       77.00    818.80
# 2                                75      1    0       49.00  1,011.60
# 3                               107      1    0       93.00    990.80
# 4                                70      1    0      100.00    996.10
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0      0.00     13.80          1.50       100.00     991.20       0.00
# 1      0.00      0.40          2.40        92.00     998.40       0.00
# 2      0.00     11.30          3.70        92.00     998.40       0.00
# 3      6.50      4.60          2.20        92.00     998.40       0.00
# 4      0.00     15.30          2.60        98.00     995.80      50.50
#
#    dest_temp  dest_wind_spd  Arrival Delay (Minutes)         Status
# 0       5.40           2.80                       51  Severely late
# 1       6.80           4.10                       -6        On-time
# 2       6.80           4.10                        1        On-time
# 3       6.80           4.10                      -10          Early
# 4      -0.70           4.20                       17           Late

# %%
required_columns2 = [ 'Flight_Number', 'Origin Airport', 'Scheduled Arrival Time',
       'Scheduled Elapsed Time (Minutes)', 'month', 'Day', 'org_clouds',
       'org_pres', 'org_snow', 'org_temp', 'org_wind_spd',
       'dest_clouds', 'dest_pres', 'dest_snow', 'dest_temp',
       'dest_wind_spd', 'Status' ]

# %%
data_before_processsing = data_before_processsing[required_columns2]

data_before_processsing.head()
data_before_processsing.info()
# Out:
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          1282            IAD                   23.17
# 1           604            DEN                   14.97
# 2          2488            EWR                   23.23
# 3          2645            ORD                   23.95
# 4          1282            IAD                   23.17
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                                70      1    6      100.00    996.90
# 1                               193      1    0       77.00    818.80
# 2                                75      1    0       49.00  1,011.60
# 3                               107      1    0       93.00    990.80
# 4                                70      1    0      100.00    996.10
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0      0.00     13.80          1.50       100.00     991.20       0.00
# 1      0.00      0.40          2.40        92.00     998.40       0.00
# 2      0.00     11.30          3.70        92.00     998.40       0.00
# 3      6.50      4.60          2.20        92.00     998.40       0.00
# 4      0.00     15.30          2.60        98.00     995.80      50.50
#
#    dest_temp  dest_wind_spd         Status
# 0       5.40           2.80  Severely late
# 1       6.80           4.10        On-time
# 2       6.80           4.10        On-time
# 3       6.80           4.10          Early
# 4      -0.70           4.20           Late
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Flight_Number                     1361 non-null   object
#  1   Origin Airport                    1361 non-null   object
#  2   Scheduled Arrival Time            1361 non-null   float64
#  3   Scheduled Elapsed Time (Minutes)  1361 non-null   int64
#  4   month                             1361 non-null   int64
#  5   Day                               1361 non-null   int64
#  6   org_clouds                        1361 non-null   float64
#  7   org_pres                          1361 non-null   float64
#  8   org_snow                          1361 non-null   float64
#  9   org_temp                          1361 non-null   float64
#  10  org_wind_spd                      1361 non-null   float64
#  11  dest_clouds                       1361 non-null   float64
#  12  dest_pres                         1361 non-null   float64
#  13  dest_snow                         1361 non-null   float64
#  14  dest_temp                         1361 non-null   float64
#  15  dest_wind_spd                     1361 non-null   float64
#  16  Status                            1361 non-null   object
# dtypes: float64(11), int64(3), object(3)
# memory usage: 180.9+ KB

# %%
categorical_varibales = ['Flight_Number', 'Origin Airport']

cvar = ['Flight_Number', 'Origin Airport', 'Status']

non_categoricalvariables = list(set(data_before_processsing.columns) - set(cvar))

print(non_categoricalvariables)
# Out:
# ['dest_clouds', 'Scheduled Elapsed Time (Minutes)', 'dest_pres', 'dest_temp', 'org_temp', 'Day', 'org_clouds', 'Scheduled Arrival Time', 'dest_snow', 'org_pres', 'org_snow', 'org_wind_spd', 'dest_wind_spd', 'month']

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
tempdata = pd.DataFrame(sc.fit_transform(data_before_processsing[non_categoricalvariables]), columns = non_categoricalvariables, index = data_before_processsing.index)

for nc in non_categoricalvariables :
    data_before_processsing[nc] = tempdata[nc]

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore',sparse=False)
dt = enc.fit(data_before_processsing[categorical_varibales])
values = dt.transform(data_before_processsing[categorical_varibales])
columnnames = enc.get_feature_names_out(categorical_varibales)
tempT = np.transpose(values)
# Out:
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
for i in range(len(tempT)) :
    data_before_processsing[columnnames[i]] = pd.DataFrame(tempT[i], index = data_before_processsing.index)
    
data_before_processsing.head()
# Out:
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          1282            IAD                    0.81
# 1           604            DEN                   -1.08
# 2          2488            EWR                    0.82
# 3          2645            ORD                    0.99
# 4          1282            IAD                    0.81
#
#    Scheduled Elapsed Time (Minutes)  month   Day  org_clouds  org_pres  \
# 0                             -1.14  -1.79  1.52        1.53      0.54
# 1                              1.48  -1.79 -1.49        0.77     -1.77
# 2                             -1.03  -1.79 -1.49       -0.15      0.73
# 3                             -0.35  -1.79 -1.49        1.30      0.46
# 4                             -1.14  -1.79 -1.49        1.53      0.53
#
#    org_snow  org_temp  ...  Flight_Number_604  Flight_Number_652  \
# 0     -0.17      0.03  ...               0.00               0.00
# 1     -0.17     -1.31  ...               1.00               0.00
# 2     -0.17     -0.22  ...               0.00               0.00
# 3      0.09     -0.89  ...               0.00               0.00
# 4     -0.17      0.18  ...               0.00               0.00
#
#    Flight_Number_702  Flight_Number_776  Flight_Number_790  Flight_Number_794  \
# 0               0.00               0.00               0.00               0.00
# 1               0.00               0.00               0.00               0.00
# 2               0.00               0.00               0.00               0.00
# 3               0.00               0.00               0.00               0.00
# 4               0.00               0.00               0.00               0.00
#
#   Origin Airport_DEN  Origin Airport_EWR  Origin Airport_IAD  \
# 0               0.00                0.00                1.00
# 1               1.00                0.00                0.00
# 2               0.00                1.00                0.00
# 3               0.00                0.00                0.00
# 4               0.00                0.00                1.00
#
#    Origin Airport_ORD
# 0                0.00
# 1                0.00
# 2                0.00
# 3                1.00
# 4                0.00
#
# [5 rows x 85 columns]

# %%
#data = pd.get_dummies(data_before_processsing.drop(columns=['Status']))
data = data_before_processsing.drop(columns=cvar)

data.head()
columns = data.columns

for v in categorical_varibales :
    if v in columns :
        print(v,'is present')

labels = data_before_processsing['Status']
labels,class_names = pd.factorize(labels)

labelsdf = pd.DataFrame(labels, index = data.index, columns = ['Status'])
print(class_names)
# Out:
#    Scheduled Arrival Time  Scheduled Elapsed Time (Minutes)  month   Day  \
# 0                    0.81                             -1.14  -1.79  1.52
# 1                   -1.08                              1.48  -1.79 -1.49
# 2                    0.82                             -1.03  -1.79 -1.49
# 3                    0.99                             -0.35  -1.79 -1.49
# 4                    0.81                             -1.14  -1.79 -1.49
#
#    org_clouds  org_pres  org_snow  org_temp  org_wind_spd  dest_clouds  ...  \
# 0        1.53      0.54     -0.17      0.03         -1.39         1.30  ...
# 1        0.77     -1.77     -0.17     -1.31         -0.79         1.00  ...
# 2       -0.15      0.73     -0.17     -0.22          0.09         1.00  ...
# 3        1.30      0.46      0.09     -0.89         -0.92         1.00  ...
# 4        1.53      0.53     -0.17      0.18         -0.65         1.23  ...
#
#    Flight_Number_604  Flight_Number_652  Flight_Number_702  Flight_Number_776  \
# 0               0.00               0.00               0.00               0.00
# 1               1.00               0.00               0.00               0.00
# 2               0.00               0.00               0.00               0.00
# 3               0.00               0.00               0.00               0.00
# 4               0.00               0.00               0.00               0.00
#
#    Flight_Number_790  Flight_Number_794  Origin Airport_DEN  \
# 0               0.00               0.00                0.00
# 1               0.00               0.00                1.00
# 2               0.00               0.00                0.00
# 3               0.00               0.00                0.00
# 4               0.00               0.00                0.00
#
#    Origin Airport_EWR  Origin Airport_IAD  Origin Airport_ORD
# 0                0.00                1.00                0.00
# 1                0.00                0.00                0.00
# 2                1.00                0.00                0.00
# 3                0.00                0.00                1.00
# 4                0.00                1.00                0.00
#
# [5 rows x 82 columns]
# Index(['Severely late', 'On-time', 'Early', 'Late'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labelsdf, test_size = 0.15, stratify=labelsdf, random_state = 42)

len(X_train)
len(X_test)

X_train.head()
y_train.head()
X_test.head()
y_test.head()
# Out:
# 1156
# 205
#      Scheduled Arrival Time  Scheduled Elapsed Time (Minutes)  month   Day  \
# 657                   -1.05                              1.61   0.00 -0.49
# 982                    0.32                             -0.14   0.90  1.02
# 846                   -1.03                              1.61   0.60  1.52
# 558                    0.91                             -1.07   0.00 -0.49
# 907                    0.94                             -0.84   0.60  0.52
#
#      org_clouds  org_pres  org_snow  org_temp  org_wind_spd  dest_clouds  ...  \
# 657        1.10     -1.64     -0.17      1.03          0.22        -0.89  ...
# 982       -0.71      0.57     -0.17      0.66         -1.06        -0.47  ...
# 846       -1.28     -1.56     -0.17      1.01         -0.05         0.21  ...
# 558        1.20      0.65     -0.17      1.23         -0.25         0.89  ...
# 907        1.50      0.82     -0.17      1.16         -1.39        -0.74  ...
#
#      Flight_Number_604  Flight_Number_652  Flight_Number_702  \
# 657               1.00               0.00               0.00
# 982               0.00               0.00               0.00
# 846               1.00               0.00               0.00
# 558               0.00               0.00               0.00
# 907               0.00               0.00               0.00
#
#      Flight_Number_776  Flight_Number_790  Flight_Number_794  \
# 657               0.00               0.00               0.00
# 982               0.00               0.00               0.00
# 846               0.00               0.00               0.00
# 558               0.00               0.00               0.00
# 907               0.00               0.00               1.00
#
#      Origin Airport_DEN  Origin Airport_EWR  Origin Airport_IAD  \
# 657                1.00                0.00                0.00
# 982                0.00                0.00                0.00
# 846                1.00                0.00                0.00
# 558                0.00                0.00                1.00
# 907                0.00                0.00                1.00
#
#      Origin Airport_ORD
# 657                0.00
# 982                1.00
# 846                0.00
# 558                0.00
# 907                0.00
#
# [5 rows x 82 columns]
#      Status
# 657       2
# 982       2
# 846       3
# 558       1
# 907       2
#       Scheduled Arrival Time  Scheduled Elapsed Time (Minutes)  month   Day  \
# 162                     0.31                             -0.31  -1.49 -0.49
# 1329                   -1.08                              1.48   1.49  1.02
# 956                    -1.03                              1.63   0.60 -0.99
# 1236                    0.28                             -0.26   1.20 -0.99
# 878                     0.94                             -0.84   0.60  1.02
#
#       org_clouds  org_pres  org_snow  org_temp  org_wind_spd  dest_clouds  \
# 162         1.53      0.41     11.66     -1.31          0.83         1.23
# 1329       -0.71     -1.61     -0.17     -3.12         -1.06         1.27
# 956        -1.70     -1.58     -0.17      0.57         -0.58        -0.51
# 1236        0.47      0.49     -0.17     -1.16          0.56         0.43
# 878        -1.31      0.77     -0.17      0.79         -0.18        -1.04
#
#       ...  Flight_Number_604  Flight_Number_652  Flight_Number_702  \
# 162   ...               0.00               0.00               0.00
# 1329  ...               1.00               0.00               0.00
# 956   ...               1.00               0.00               0.00
# 1236  ...               0.00               0.00               0.00
# 878   ...               0.00               0.00               0.00
#
#       Flight_Number_776  Flight_Number_790  Flight_Number_794  \
# 162                0.00               0.00               0.00
# 1329               0.00               0.00               0.00
# 956                0.00               0.00               0.00
# 1236               0.00               0.00               0.00
# 878                0.00               0.00               1.00
#
#       Origin Airport_DEN  Origin Airport_EWR  Origin Airport_IAD  \
# 162                 0.00                0.00                0.00
# 1329                1.00                0.00                0.00
# 956                 1.00                0.00                0.00
# 1236                0.00                0.00                0.00
# 878                 0.00                0.00                1.00
#
#       Origin Airport_ORD
# 162                 1.00
# 1329                0.00
# 956                 0.00
# 1236                1.00
# 878                 0.00
#
# [5 rows x 82 columns]
#       Status
# 162        2
# 1329       3
# 956        1
# 1236       2
# 878        2

# %%
# Fitting Classifier to the Training Set
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

#classifier = DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=42)
classifier =  RandomForestClassifier(n_estimators=100,criterion='gini', max_depth=4, random_state=42)
classifier.fit(X_train, y_train)
# Out:
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/1902297743.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(X_train, y_train)
# RandomForestClassifier(max_depth=4, random_state=42)

# %%
classifier.score(X_train,y_train)
# Out:
# 0.5129757785467128

# %%
# Model performance on training set
y_pred_train =pd.DataFrame(classifier.predict(X_train), index = X_train.index, columns = ['rf_pred'])
y_pred_train.head()
# Out:
#      rf_pred
# 657        1
# 982        2
# 846        1
# 558        1
# 907        2

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

# %%
accuracy = metrics.accuracy_score(y_train, y_pred_train)
print("Accuracy: {:.2f}".format(accuracy))
cm=confusion_matrix(y_train,y_pred_train)
print('Confusion Matrix: \n', cm)
print(classification_report(y_train, y_pred_train, target_names=class_names))
# Out:
# Accuracy: 0.51
# Confusion Matrix:
#  [[  1 139  13   0]
#  [  0 474  22   0]
#  [  0 251 118   0]
#  [  0 131   7   0]]
#                precision    recall  f1-score   support
#
# Severely late       1.00      0.01      0.01       153
#       On-time       0.48      0.96      0.64       496
#         Early       0.74      0.32      0.45       369
#          Late       0.00      0.00      0.00       138
#
#      accuracy                           0.51      1156
#     macro avg       0.55      0.32      0.27      1156
#  weighted avg       0.57      0.51      0.42      1156
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Model performance on training set
y_pred_test =pd.DataFrame(classifier.predict(X_test), index = X_test.index, columns = ['rf_pred'])
y_pred_test.head()
# Out:
#       rf_pred
# 162         1
# 1329        1
# 956         1
# 1236        1
# 878         2

# %%
accuracy = metrics.accuracy_score(y_test, y_pred_test)
print("Accuracy: {:.2f}".format(accuracy))

from sklearn.metrics import confusion_matrix, classification_report
cm=confusion_matrix(y_test,y_pred_test)
print('Confusion Matrix: \n', cm)
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
# Accuracy: 0.47
# Confusion Matrix:
#  [[ 0 25  2  0]
#  [ 0 81  7  0]
#  [ 0 50 15  0]
#  [ 0 24  1  0]]
#                precision    recall  f1-score   support
#
# Severely late       0.00      0.00      0.00        27
#       On-time       0.45      0.92      0.60        88
#         Early       0.60      0.23      0.33        65
#          Late       0.00      0.00      0.00        25
#
#      accuracy                           0.47       205
#     macro avg       0.26      0.29      0.23       205
#  weighted avg       0.38      0.47      0.37       205
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def addOutputRF(features,ouput) :
    x_train_with_op =  features.copy()
    x_train_with_op = x_train_with_op.merge(ouput, left_index = True, right_index = True)
    return x_train_with_op

# %%
xrf_train = addOutputRF(X_train,y_pred_train)
xrf_test = addOutputRF(X_test,y_pred_test)

xrf_train.head()
xrf_test.head()
# Out:
#      Scheduled Arrival Time  Scheduled Elapsed Time (Minutes)  month   Day  \
# 657                   -1.05                              1.61   0.00 -0.49
# 982                    0.32                             -0.14   0.90  1.02
# 846                   -1.03                              1.61   0.60  1.52
# 558                    0.91                             -1.07   0.00 -0.49
# 907                    0.94                             -0.84   0.60  0.52
#
#      org_clouds  org_pres  org_snow  org_temp  org_wind_spd  dest_clouds  ...  \
# 657        1.10     -1.64     -0.17      1.03          0.22        -0.89  ...
# 982       -0.71      0.57     -0.17      0.66         -1.06        -0.47  ...
# 846       -1.28     -1.56     -0.17      1.01         -0.05         0.21  ...
# 558        1.20      0.65     -0.17      1.23         -0.25         0.89  ...
# 907        1.50      0.82     -0.17      1.16         -1.39        -0.74  ...
#
#      Flight_Number_652  Flight_Number_702  Flight_Number_776  \
# 657               0.00               0.00               0.00
# 982               0.00               0.00               0.00
# 846               0.00               0.00               0.00
# 558               0.00               0.00               0.00
# 907               0.00               0.00               0.00
#
#      Flight_Number_790  Flight_Number_794  Origin Airport_DEN  \
# 657               0.00               0.00                1.00
# 982               0.00               0.00                0.00
# 846               0.00               0.00                1.00
# 558               0.00               0.00                0.00
# 907               0.00               1.00                0.00
#
#      Origin Airport_EWR  Origin Airport_IAD  Origin Airport_ORD  rf_pred
# 657                0.00                0.00                0.00        1
# 982                0.00                0.00                1.00        2
# 846                0.00                0.00                0.00        1
# 558                0.00                1.00                0.00        1
# 907                0.00                1.00                0.00        2
#
# [5 rows x 83 columns]
#       Scheduled Arrival Time  Scheduled Elapsed Time (Minutes)  month   Day  \
# 162                     0.31                             -0.31  -1.49 -0.49
# 1329                   -1.08                              1.48   1.49  1.02
# 956                    -1.03                              1.63   0.60 -0.99
# 1236                    0.28                             -0.26   1.20 -0.99
# 878                     0.94                             -0.84   0.60  1.02
#
#       org_clouds  org_pres  org_snow  org_temp  org_wind_spd  dest_clouds  \
# 162         1.53      0.41     11.66     -1.31          0.83         1.23
# 1329       -0.71     -1.61     -0.17     -3.12         -1.06         1.27
# 956        -1.70     -1.58     -0.17      0.57         -0.58        -0.51
# 1236        0.47      0.49     -0.17     -1.16          0.56         0.43
# 878        -1.31      0.77     -0.17      0.79         -0.18        -1.04
#
#       ...  Flight_Number_652  Flight_Number_702  Flight_Number_776  \
# 162   ...               0.00               0.00               0.00
# 1329  ...               0.00               0.00               0.00
# 956   ...               0.00               0.00               0.00
# 1236  ...               0.00               0.00               0.00
# 878   ...               0.00               0.00               0.00
#
#       Flight_Number_790  Flight_Number_794  Origin Airport_DEN  \
# 162                0.00               0.00                0.00
# 1329               0.00               0.00                1.00
# 956                0.00               0.00                1.00
# 1236               0.00               0.00                0.00
# 878                0.00               1.00                0.00
#
#       Origin Airport_EWR  Origin Airport_IAD  Origin Airport_ORD  rf_pred
# 162                 0.00                0.00                1.00        1
# 1329                0.00                0.00                0.00        1
# 956                 0.00                0.00                0.00        1
# 1236                0.00                0.00                1.00        1
# 878                 0.00                1.00                0.00        2
#
# [5 rows x 83 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=15)

# %%
knn.fit(xrf_train, y_train)
# Out:
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=15)

# %%
knn.score(xrf_train, y_train)
# Out:
# 0.5294117647058824

# %%
knn_pred = pd.DataFrame(knn.predict(xrf_test), index = xrf_test.index, columns = ['knn_pred'])

# %%
accuracy = metrics.accuracy_score(y_test, knn_pred)
print("Accuracy: {:.2f}".format(accuracy))

from sklearn.metrics import confusion_matrix, classification_report
cm=confusion_matrix(y_test,knn_pred)
print('Confusion Matrix: \n', cm)
print(classification_report(y_test, knn_pred, target_names=class_names))
# Out:
# Accuracy: 0.40
# Confusion Matrix:
#  [[ 3 18  6  0]
#  [ 4 61 23  0]
#  [ 3 45 17  0]
#  [ 2 19  3  1]]
#                precision    recall  f1-score   support
#
# Severely late       0.25      0.11      0.15        27
#       On-time       0.43      0.69      0.53        88
#         Early       0.35      0.26      0.30        65
#          Late       1.00      0.04      0.08        25
#
#      accuracy                           0.40       205
#     macro avg       0.51      0.28      0.26       205
#  weighted avg       0.45      0.40      0.35       205

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=50, min_samples_split = 60, min_samples_leaf = 4, max_depth = 5, n_estimators = 70)

gb = gb.fit(xrf_train, y_train) 
gb.score(xrf_train, y_train)
# Out:
# /Users/shivakumarsuresh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7923875432525952

# %%
test_output = pd.DataFrame(gb.predict(xrf_test), index = xrf_test.index, columns = ['pred_Y'])
test_output = test_output.merge(y_test, left_index = True, right_index = True)
test_output.head()
print('Fraction of correct classification ')
gb.score(xrf_test, y_test)
# Out:
#       pred_Y  Status
# 162        1       2
# 1329       1       3
# 956        1       1
# 1236       1       2
# 878        2       2
# Fraction of correct classification
# 0.3804878048780488

# %%
predict_Apr_Data = pd.read_csv('predict_Arrivals.csv',parse_dates = ["Date"])
predict_Apr_Data.head()
predict_Apr_Data.info()
# Out:
#         Date       Day Origin Airport Flight Number Arrival Time  \
# 0 2023-04-21    Friday            ORD       UA 3839     10:00 AM
# 1 2023-04-21    Friday            ORD       UA 3524      4:50 PM
# 2 2023-04-21    Friday            ORD        UA 538      9:34 PM
# 3 2023-04-22  Saturday            ORD       UA 3839     10:00 AM
# 4 2023-04-22  Saturday            ORD       UA 3524      4:50 PM
#
#    Scheduled Elapsed Time (Minutes)  month  org_clouds  org_pres  org_snow  \
# 0                               110  April          82    991.30      0.00
# 1                               115  April          82    991.30      0.00
# 2                               114  April          82    991.30      0.00
# 3                               110  April          77    987.80      0.00
# 4                               115  April          77    987.80      0.00
#
#    org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  dest_temp  \
# 0     11.00          4.00           54     997.30          0      17.50
# 1     11.00          4.00           54     997.30          0      17.50
# 2     11.00          4.00           54     997.30          0      17.50
# 3      6.30          4.80           74     984.50          0      16.10
# 4      6.30          4.80           74     984.50          0      16.10
#
#    dest_wind_spd
# 0           3.00
# 1           3.00
# 2           3.00
# 3           4.60
# 4           4.60
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              32 non-null     datetime64[ns]
#  1   Day                               32 non-null     object
#  2   Origin Airport                    32 non-null     object
#  3   Flight Number                     32 non-null     object
#  4   Arrival Time                      32 non-null     object
#  5   Scheduled Elapsed Time (Minutes)  32 non-null     int64
#  6   month                             32 non-null     object
#  7   org_clouds                        32 non-null     int64
#  8   org_pres                          32 non-null     float64
#  9   org_snow                          32 non-null     float64
#  10  org_temp                          32 non-null     float64
#  11  org_wind_spd                      32 non-null     float64
#  12  dest_clouds                       32 non-null     int64
#  13  dest_pres                         32 non-null     float64
#  14  dest_snow                         32 non-null     int64
#  15  dest_temp                         32 non-null     float64
#  16  dest_wind_spd                     32 non-null     float64
# dtypes: datetime64[ns](1), float64(7), int64(4), object(5)
# memory usage: 4.4+ KB

# %%
print(predict_Apr_Data['Flight Number'].head())
# Out:
# 0    UA 3839
# 1    UA 3524
# 2     UA 538
# 3    UA 3839
# 4    UA 3524
# Name: Flight Number, dtype: object

# %%
predict_Apr_Data['Flight_Number'] = predict_Apr_Data['Flight Number'].apply(lambda x : x.split(" ")[1])
predict_Apr_Data['Scheduled Arrival Time'] = pd.to_datetime(predict_Apr_Data['Arrival Time']).dt.time
predict_Apr_Data['Scheduled Arrival Time'] = predict_Apr_Data['Scheduled Arrival Time'] .astype(str)

predict_Apr_Data['Scheduled Arrival Time'] = predict_Apr_Data['Scheduled Arrival Time'].apply(lambda x : (float(x.split(":")[0]) + float(x.split(":")[1])/60.0)) 

predict_Apr_Data['month'] = predict_Apr_Data['month'].apply(lambda x : month_labels.index(x) +1 )
predict_Apr_Data['Day'] = predict_Apr_Data['Date'].dt.strftime('%w')
predict_Apr_Data['Day'] = predict_Apr_Data['Date'].dt.strftime('%w').astype(int)

predict_Apr_Data.info()
predict_Apr_Data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              32 non-null     datetime64[ns]
#  1   Day                               32 non-null     int64
#  2   Origin Airport                    32 non-null     object
#  3   Flight Number                     32 non-null     object
#  4   Arrival Time                      32 non-null     object
#  5   Scheduled Elapsed Time (Minutes)  32 non-null     int64
#  6   month                             32 non-null     int64
#  7   org_clouds                        32 non-null     int64
#  8   org_pres                          32 non-null     float64
#  9   org_snow                          32 non-null     float64
#  10  org_temp                          32 non-null     float64
#  11  org_wind_spd                      32 non-null     float64
#  12  dest_clouds                       32 non-null     int64
#  13  dest_pres                         32 non-null     float64
#  14  dest_snow                         32 non-null     int64
#  15  dest_temp                         32 non-null     float64
#  16  dest_wind_spd                     32 non-null     float64
#  17  Flight_Number                     32 non-null     object
#  18  Scheduled Arrival Time            32 non-null     float64
# dtypes: datetime64[ns](1), float64(8), int64(6), object(4)
# memory usage: 4.9+ KB
#         Date  Day Origin Airport Flight Number Arrival Time  \
# 0 2023-04-21    5            ORD       UA 3839     10:00 AM
# 1 2023-04-21    5            ORD       UA 3524      4:50 PM
# 2 2023-04-21    5            ORD        UA 538      9:34 PM
# 3 2023-04-22    6            ORD       UA 3839     10:00 AM
# 4 2023-04-22    6            ORD       UA 3524      4:50 PM
#
#    Scheduled Elapsed Time (Minutes)  month  org_clouds  org_pres  org_snow  \
# 0                               110      4          82    991.30      0.00
# 1                               115      4          82    991.30      0.00
# 2                               114      4          82    991.30      0.00
# 3                               110      4          77    987.80      0.00
# 4                               115      4          77    987.80      0.00
#
#    org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  dest_temp  \
# 0     11.00          4.00           54     997.30          0      17.50
# 1     11.00          4.00           54     997.30          0      17.50
# 2     11.00          4.00           54     997.30          0      17.50
# 3      6.30          4.80           74     984.50          0      16.10
# 4      6.30          4.80           74     984.50          0      16.10
#
#    dest_wind_spd Flight_Number  Scheduled Arrival Time
# 0           3.00          3839                   10.00
# 1           3.00          3524                   16.83
# 2           3.00           538                   21.57
# 3           4.60          3839                   10.00
# 4           4.60          3524                   16.83

# %%
predict_Apr_Data['org_clouds'] = predict_Apr_Data['org_clouds'].astype(float)
predict_Apr_Data['dest_clouds'] = predict_Apr_Data['dest_clouds'].astype(float)

# %%
selectf = [ 'Flight_Number', 'Origin Airport', 'Scheduled Arrival Time',
       'Scheduled Elapsed Time (Minutes)', 'month', 'Day', 'org_clouds',
       'org_pres', 'org_snow', 'org_temp', 'org_wind_spd',
       'dest_clouds', 'dest_pres', 'dest_snow', 'dest_temp',
       'dest_wind_spd' ]

# %%
databefore_scaling = predict_Apr_Data[selectf]
databefore_scaling.head()
# Out:
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          3839            ORD                   10.00
# 1          3524            ORD                   16.83
# 2           538            ORD                   21.57
# 3          3839            ORD                   10.00
# 4          3524            ORD                   16.83
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                               110      4    5       82.00    991.30
# 1                               115      4    5       82.00    991.30
# 2                               114      4    5       82.00    991.30
# 3                               110      4    6       77.00    987.80
# 4                               115      4    6       77.00    987.80
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0      0.00     11.00          4.00        54.00     997.30          0
# 1      0.00     11.00          4.00        54.00     997.30          0
# 2      0.00     11.00          4.00        54.00     997.30          0
# 3      0.00      6.30          4.80        74.00     984.50          0
# 4      0.00      6.30          4.80        74.00     984.50          0
#
#    dest_temp  dest_wind_spd
# 0      17.50           3.00
# 1      17.50           3.00
# 2      17.50           3.00
# 3      16.10           4.60
# 4      16.10           4.60

# %%
tempdata = pd.DataFrame(sc.transform(databefore_scaling[non_categoricalvariables]), columns = non_categoricalvariables, index = databefore_scaling.index)

for nc in non_categoricalvariables :
    databefore_scaling[nc] = tempdata[nc]
    
databefore_scaling.head()
# Out:
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/560115840.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   databefore_scaling[nc] = tempdata[nc]
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          3839            ORD                   -2.22
# 1          3524            ORD                   -0.65
# 2           538            ORD                    0.44
# 3          3839            ORD                   -2.22
# 4          3524            ORD                   -0.65
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                             -0.29  -0.89 1.02        0.94      0.46
# 1                             -0.18  -0.89 1.02        0.94      0.46
# 2                             -0.20  -0.89 1.02        0.94      0.46
# 3                             -0.29  -0.89 1.52        0.77      0.42
# 4                             -0.18  -0.89 1.52        0.77      0.42
#
#    org_snow  org_temp  org_wind_spd  dest_clouds  dest_pres  dest_snow  \
# 0     -0.17     -0.25          0.29        -0.44      -0.57      -0.19
# 1     -0.17     -0.25          0.29        -0.44      -0.57      -0.19
# 2     -0.17     -0.25          0.29        -0.44      -0.57      -0.19
# 3     -0.17     -0.72          0.83         0.32      -2.49      -0.19
# 4     -0.17     -0.72          0.83         0.32      -2.49      -0.19
#
#    dest_temp  dest_wind_spd
# 0       0.57          -0.52
# 1       0.57          -0.52
# 2       0.57          -0.52
# 3       0.43           0.55
# 4       0.43           0.55

# %%
values2 = dt.transform(databefore_scaling[categorical_varibales])
tempT2 = np.transpose(values2)

# %%
for i in range(len(tempT2)) :
    databefore_scaling[columnnames[i]] = pd.DataFrame(tempT2[i], index = databefore_scaling.index)
    
databefore_scaling.head()
# Out:
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/2886333798.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   databefore_scaling[columnnames[i]] = pd.DataFrame(tempT2[i], index = databefore_scaling.index)
# /var/folders/55/q6qn1ybn5wb_dy_w_7phcrfm0000gn/T/ipykernel_66247/2886333798.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   databefore_scaling[columnnames[i]] = pd.DataFrame(tempT2[i], index = databefore_scaling.index)
#   Flight_Number Origin Airport  Scheduled Arrival Time  \
# 0          3839            ORD                   -2.22
# 1          3524            ORD                   -0.65
# 2           538            ORD                    0.44
# 3          3839            ORD                   -2.22
# 4          3524            ORD                   -0.65
#
#    Scheduled Elapsed Time (Minutes)  month  Day  org_clouds  org_pres  \
# 0                             -0.29  -0.89 1.02        0.94      0.46
# 1                             -0.18  -0.89 1.02        0.94      0.46
# 2                             -0.20  -0.89 1.02        0.94      0.46
# 3                             -0.29  -0.89 1.52        0.77      0.42
# 4                             -0.18  -0.89 1.52        0.77      0.42
#
#    org_snow  org_temp  ...  Flight_Number_604  Flight_Number_652  \
# 0     -0.17     -0.25  ...               0.00               0.00
# 1     -0.17     -0.25  ...               0.00               0.00
# 2     -0.17     -0.25  ...               0.00               0.00
# 3     -0.17     -0.72  ...               0.00               0.00
# 4     -0.17     -0.72  ...               0.00               0.00
#
#    Flight_Number_702  Flight_Number_776  Flight_Number_790  Flight_Number_794  \
# 0               0.00               0.00               0.00               0.00
# 1               0.00               0.00               0.00               0.00
# 2               0.00               0.00               0.00               0.00
# 3               0.00               0.00               0.00               0.00
# 4               0.00               0.00               0.00               0.00
#
#    Origin Airport_DEN  Origin Airport_EWR  Origin Airport_IAD  \
# 0                0.00                0.00                0.00
# 1                0.00                0.00                0.00
# 2                0.00                0.00                0.00
# 3                0.00                0.00                0.00
# 4                0.00                0.00                0.00
#
#    Origin Airport_ORD
# 0                1.00
# 1                1.00
# 2                1.00
# 3                1.00
# 4                1.00
#
# [5 rows x 84 columns]

# %%
apr_pred_featues = databefore_scaling[X_train.columns]
apr_pred_featues.head(33)
# Out:
#     Scheduled Arrival Time  Scheduled Elapsed Time (Minutes)  month   Day  \
# 0                    -2.22                             -0.29  -0.89  1.02
# 1                    -0.65                             -0.18  -0.89  1.02
# 2                     0.44                             -0.20  -0.89  1.02
# 3                    -2.22                             -0.29  -0.89  1.52
# 4                    -0.65                             -0.18  -0.89  1.52
# 5                     0.44                             -0.20  -0.89  1.52
# 6                    -2.22                             -0.29  -0.89 -1.49
# 7                    -0.63                             -0.18  -0.89 -1.49
# 8                     0.44                             -0.20  -0.89 -1.49
# 9                    -2.22                             -0.29  -0.89 -0.99
# 10                   -0.65                             -0.18  -0.89 -0.99
# 11                    0.44                             -0.20  -0.89 -0.99
# 12                   -1.02                              1.65  -0.89  1.02
# 13                   -1.02                              1.65  -0.89  1.52
# 14                   -1.02                              1.65  -0.89 -1.49
# 15                   -1.02                              1.65  -0.89 -0.99
# 16                   -2.04                             -0.69  -0.89  1.02
# 17                    0.93                             -1.09  -0.89  1.02
# 18                   -2.04                             -0.69  -0.89  1.52
# 19                    0.84                             -1.09  -0.89  1.52
# 20                   -2.04                             -0.69  -0.89 -1.49
# 21                    0.93                             -1.09  -0.89 -1.49
# 22                   -2.04                             -0.69  -0.89 -0.99
# 23                    0.93                             -1.09  -0.89 -0.99
# 24                   -1.31                             -1.05  -0.89  1.02
# 25                   -0.15                             -0.86  -0.89  1.02
# 26                   -1.31                             -1.03  -0.89  1.52
# 27                   -0.15                             -0.86  -0.89  1.52
# 28                   -1.31                             -1.05  -0.89 -1.49
# 29                   -0.15                             -0.86  -0.89 -1.49
# 30                   -1.31                             -1.05  -0.89 -0.99
# 31                   -0.15                             -0.86  -0.89 -0.99
#
#     org_clouds  org_pres  org_snow  org_temp  org_wind_spd  dest_clouds  ...  \
# 0         0.94      0.46     -0.17     -0.25          0.29        -0.44  ...
# 1         0.94      0.46     -0.17     -0.25          0.29        -0.44  ...
# 2         0.94      0.46     -0.17     -0.25          0.29        -0.44  ...
# 3         0.77      0.42     -0.17     -0.72          0.83         0.32  ...
# 4         0.77      0.42     -0.17     -0.72          0.83         0.32  ...
# 5         0.77      0.42     -0.17     -0.72          0.83         0.32  ...
# 6         1.23      0.50     -0.17     -0.79          0.43         0.24  ...
# 7         1.23      0.50     -0.17     -0.79          0.43         0.24  ...
# 8         1.23      0.50     -0.17     -0.79          0.43         0.24  ...
# 9        -0.55      0.55     -0.17     -0.68         -0.58         0.62  ...
# 10       -0.55      0.55     -0.17     -0.68         -0.58         0.62  ...
# 11       -0.55      0.55     -0.17     -0.68         -0.58         0.62  ...
# 12        0.31     -1.53     -0.17     -0.89          0.36        -0.44  ...
# 13        1.46     -1.54      0.70     -0.99         -0.85         0.32  ...
# 14        0.90     -1.58     -0.17     -0.53         -1.12         0.24  ...
# 15       -0.55     -1.62     -0.17     -0.26         -1.33         0.62  ...
# 16       -0.52      0.81     -0.17     -0.08         -0.25        -0.44  ...
# 17       -0.52      0.81     -0.17     -0.08         -0.25        -0.44  ...
# 18        0.71      0.69     -0.17      0.17          0.83         0.32  ...
# 19        0.71      0.69     -0.17      0.17          0.83         0.32  ...
# 20        0.01      0.62     -0.17      0.24          0.02         0.24  ...
# 21        0.01      0.62     -0.17      0.24          0.02         0.24  ...
# 22       -0.55      0.68     -0.17      0.06          0.76         0.62  ...
# 23       -0.55      0.68     -0.17      0.06          0.76         0.62  ...
# 24       -1.47      0.73     -0.17      0.89         -0.99        -0.44  ...
# 25       -1.47      0.73     -0.17      0.89         -0.99        -0.44  ...
# 26        0.04      0.62     -0.17      0.55          0.56         0.32  ...
# 27        0.04      0.62     -0.17      0.55          0.56         0.32  ...
# 28       -0.35      0.63     -0.17      0.14          0.16         0.24  ...
# 29       -0.35      0.63     -0.17      0.14          0.16         0.24  ...
# 30       -0.88      0.69     -0.17      0.09          1.03         0.62  ...
# 31       -0.88      0.69     -0.17      0.09          1.03         0.62  ...
#
#     Flight_Number_604  Flight_Number_652  Flight_Number_702  \
# 0                0.00               0.00               0.00
# 1                0.00               0.00               0.00
# 2                0.00               0.00               0.00
# 3                0.00               0.00               0.00
# 4                0.00               0.00               0.00
# 5                0.00               0.00               0.00
# 6                0.00               0.00               0.00
# 7                0.00               0.00               0.00
# 8                0.00               0.00               0.00
# 9                0.00               0.00               0.00
# 10               0.00               0.00               0.00
# 11               0.00               0.00               0.00
# 12               1.00               0.00               0.00
# 13               1.00               0.00               0.00
# 14               1.00               0.00               0.00
# 15               1.00               0.00               0.00
# 16               0.00               0.00               0.00
# 17               0.00               0.00               0.00
# 18               0.00               0.00               0.00
# 19               0.00               0.00               0.00
# 20               0.00               0.00               0.00
# 21               0.00               0.00               0.00
# 22               0.00               0.00               0.00
# 23               0.00               0.00               0.00
# 24               0.00               0.00               0.00
# 25               0.00               0.00               0.00
# 26               0.00               0.00               0.00
# 27               0.00               0.00               0.00
# 28               0.00               0.00               0.00
# 29               0.00               0.00               0.00
# 30               0.00               0.00               0.00
# 31               0.00               0.00               0.00
#
#     Flight_Number_776  Flight_Number_790  Flight_Number_794  \
# 0                0.00               0.00               0.00
# 1                0.00               0.00               0.00
# 2                0.00               0.00               0.00
# 3                0.00               0.00               0.00
# 4                0.00               0.00               0.00
# 5                0.00               0.00               0.00
# 6                0.00               0.00               0.00
# 7                0.00               0.00               0.00
# 8                0.00               0.00               0.00
# 9                0.00               0.00               0.00
# 10               0.00               0.00               0.00
# 11               0.00               0.00               0.00
# 12               0.00               0.00               0.00
# 13               0.00               0.00               0.00
# 14               0.00               0.00               0.00
# 15               0.00               0.00               0.00
# 16               0.00               0.00               0.00
# 17               0.00               0.00               0.00
# 18               0.00               0.00               0.00
# 19               0.00               0.00               0.00
# 20               0.00               0.00               0.00
# 21               0.00               0.00               0.00
# 22               0.00               0.00               0.00
# 23               0.00               0.00               0.00
# 24               0.00               0.00               0.00
# 25               0.00               0.00               0.00
# 26               0.00               0.00               0.00
# 27               0.00               0.00               0.00
# 28               0.00               0.00               0.00
# 29               0.00               0.00               0.00
# 30               0.00               0.00               0.00
# 31               0.00               0.00               0.00
#
#     Origin Airport_DEN  Origin Airport_EWR  Origin Airport_IAD  \
# 0                 0.00                0.00                0.00
# 1                 0.00                0.00                0.00
# 2                 0.00                0.00                0.00
# 3                 0.00                0.00                0.00
# 4                 0.00                0.00                0.00
# 5                 0.00                0.00                0.00
# 6                 0.00                0.00                0.00
# 7                 0.00                0.00                0.00
# 8                 0.00                0.00                0.00
# 9                 0.00                0.00                0.00
# 10                0.00                0.00                0.00
# 11                0.00                0.00                0.00
# 12                1.00                0.00                0.00
# 13                1.00                0.00                0.00
# 14                1.00                0.00                0.00
# 15                1.00                0.00                0.00
# 16                0.00                1.00                0.00
# 17                0.00                1.00                0.00
# 18                0.00                1.00                0.00
# 19                0.00                1.00                0.00
# 20                0.00                1.00                0.00
# 21                0.00                1.00                0.00
# 22                0.00                1.00                0.00
# 23                0.00                1.00                0.00
# 24                0.00                0.00                1.00
# 25                0.00                0.00                1.00
# 26                0.00                0.00                1.00
# 27                0.00                0.00                1.00
# 28                0.00                0.00                1.00
# 29                0.00                0.00                1.00
# 30                0.00                0.00                1.00
# 31                0.00                0.00                1.00
#
#     Origin Airport_ORD
# 0                 1.00
# 1                 1.00
# 2                 1.00
# 3                 1.00
# 4                 1.00
# 5                 1.00
# 6                 1.00
# 7                 1.00
# 8                 1.00
# 9                 1.00
# 10                1.00
# 11                1.00
# 12                0.00
# 13                0.00
# 14                0.00
# 15                0.00
# 16                0.00
# 17                0.00
# 18                0.00
# 19                0.00
# 20                0.00
# 21                0.00
# 22                0.00
# 23                0.00
# 24                0.00
# 25                0.00
# 26                0.00
# 27                0.00
# 28                0.00
# 29                0.00
# 30                0.00
# 31                0.00
#
# [32 rows x 82 columns]

# %%
apr_pred_test =pd.DataFrame(classifier.predict(apr_pred_featues), index = apr_pred_featues.index, columns = ['Status (Early, On-time, Late, Severly Late)'])
apr_pred_test.head()
# Out:
#    pred
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
classnames = list(class_names)

apr_pred_test['Status (Early, On-time, Late, Severly Late)'] = apr_pred_test['Status (Early, On-time, Late, Severly Late)'].apply(lambda x : classnames[x])
apr_pred_test.head()
# Out:
#       pred
# 0  On-time
# 1  On-time
# 2  On-time
# 3  On-time
# 4  On-time

# %%
select_columns = ['Date','Day', 'Origin Airport', 'Flight Number', 'Arrival Time']
pred_data = predict_Apr_Data[select_columns]
pred_data = pred_data.merge(apr_pred_test, left_index = True, right_index = True)
pred_data.head()
# Out:
#         Date  Day Origin Airport Flight Number Arrival Time     pred
# 0 2023-04-21    5            ORD       UA 3839     10:00 AM  On-time
# 1 2023-04-21    5            ORD       UA 3524      4:50 PM  On-time
# 2 2023-04-21    5            ORD        UA 538      9:34 PM  On-time
# 3 2023-04-22    6            ORD       UA 3839     10:00 AM  On-time
# 4 2023-04-22    6            ORD       UA 3524      4:50 PM  On-time

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            32 non-null     datetime64[ns]
#  1   Day             32 non-null     int64
#  2   Origin Airport  32 non-null     object
#  3   Flight Number   32 non-null     object
#  4   Arrival Time    32 non-null     object
#  5   pred            32 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 1.6+ KB

# %%
pred_data['Date'] = pred_data['Date'].dt.strftime('%m/%d/%Y')
pred_data.head()
# Out:
#          Date  Day Origin Airport Flight Number Arrival Time     pred
# 0  04/21/2023    5            ORD       UA 3839     10:00 AM  On-time
# 1  04/21/2023    5            ORD       UA 3524      4:50 PM  On-time
# 2  04/21/2023    5            ORD        UA 538      9:34 PM  On-time
# 3  04/22/2023    6            ORD       UA 3839     10:00 AM  On-time
# 4  04/22/2023    6            ORD       UA 3524      4:50 PM  On-time

# %%
pred_data.to_csv("predicted_results.csv",index=False)
